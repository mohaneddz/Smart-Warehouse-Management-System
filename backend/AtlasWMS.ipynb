# %% [markdown]
# ![ensia-logo.png](data:image/png;base64,...)

# %% [markdown]
# # Atlas WMS
#
#
# # Intro to AI
# **Date of Submission**: 10 mai 2025
# **Supervisor**: Ahmed Guessoum
#
# ---
#
# ## Table of Contents
#
# 1. [Greedy Algorithm](#greedy-algorithm)
# 2. [A* Search](#a-search)
# 3. [Genetic Algorithm](#genetic-algorithm)
# 4. [Simulated Annealing](#simulated-annealing)
# 5. [Constraint Satisfaction Problems (CSP)](#constraint-satisfaction-problems-csp)

# %% [markdown]
# #

# %% [markdown]
# ## Greedy Algorithm

# %% [markdown]
# ## A* Search

# %% [markdown]
# ## Genetic Algorithm

# %% [markdown]
# ## Simulated Annealing

# %% [markdown]
# ## Constraint Satisfaction Problems (CSP)
